# %%
# =====================================
# NOTEBOOK : NB_CONNECTION
# PURPOSE  : COMMON JDBC CONNECTIONS
# =====================================

# %%
# =====================================
# COMMON CONNECTIONS
# =====================================

jdbcHostname = "ods-rajes-azure.database.windows.net"
jdbcPort = 1433

srcJdbcDatabase = "SRC_ODS"

srcJdbcUrl = (
    f"jdbc:sqlserver://{jdbcHostname}:{jdbcPort};"
    f"database={srcJdbcDatabase};"
    "encrypt=true;"
    "trustServerCertificate=false;"
    "hostNameInCertificate=*.database.windows.net;"
    "loginTimeout=30;"
)

connectionProperties = {
    "user": "sqladmin",
    "password": "Rajeshsara@01",
    "driver": "com.microsoft.sqlserver.jdbc.SQLServerDriver"
}

print("Source Connection Loaded Successfully")
