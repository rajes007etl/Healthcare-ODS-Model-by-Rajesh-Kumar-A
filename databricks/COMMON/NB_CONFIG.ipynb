# %%
# =====================================
# NOTEBOOK : NB_CONFIG
# PURPOSE  : PROJECT CONFIGURATION
# =====================================

catalog_name = "databricks_ods"

silver_schema = "SILVER"
gold_schema   = "GOLD"

# Silver tables
ods_member_table  = f"{catalog_name}.{silver_schema}.ODS_MEMBER"
ods_provider_table= f"{catalog_name}.{silver_schema}.ODS_PROVIDER"
ods_claim_table   = f"{catalog_name}.{silver_schema}.ODS_CLAIM"
ods_payment_table = f"{catalog_name}.{silver_schema}.ODS_PAYMENT"

# Gold tables
dim_member_table   = f"{catalog_name}.{gold_schema}.DIM_MEMBER"
dim_provider_table = f"{catalog_name}.{gold_schema}.DIM_PROVIDER"
dim_date_table     = f"{catalog_name}.{gold_schema}.DIM_DATE"
fact_claim_table   = f"{catalog_name}.{gold_schema}.FACT_CLAIM"
fact_payment_table = f"{catalog_name}.{gold_schema}.FACT_PAYMENT"
